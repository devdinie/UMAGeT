# %%
import os
import numpy as np
import nibabel as nib
import nilearn
import torchio
import SimpleITK as sitk
from nilearn import plotting
# Out:
# /home/swapna91/virtualenvs/Uvenv2/lib/python3.7/site-packages/nilearn/datasets/__init__.py:90: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
add_ghosts = torchio.RandomGhosting(num_ghosts=np.int(no_ghosts), intensity=1)

# %%
path = "/home/swapna91/scratch/UMAGeT_21v1/data/data_aug"
img1 = nib.load(os.path.join(path,"brains","CC420089_t1_norm1-rC0-n0-d0-gh1-sp1.nii"))
msk1 = nib.load(os.path.join(path,"target_labels","CC420089_labels_norm1-rC0-n0-d0-gh1-sp1.nii"))

#img2 = nib.load(os.path.join(path,"brains","CC621128_t1_norm1-rC0-n0-d0-gh2-sp0.nii"))
#msk2 = nib.load(os.path.join(path,"target_labels","CC621128_labels_norm1-rC0-n0-d0-gh2-sp0.nii"))

#plotting.plot_roi(roi_img=msk2, bg_img=img2, cmap="jet_r",axes=None)
plotting.plot_roi(roi_img=msk1, bg_img=img1, cmap="jet_r",axes=None)
